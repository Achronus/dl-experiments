# %%
from pathlib import Path
import math

import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %matplotlib inline

# %%
img_path = Path(Path.cwd(), 'imgs', 'alfalfa.jpg')
img = cv.imread(img_path)
img = cv.cvtColor(img, cv.COLOR_RGB2GRAY)

# %%
imgplot = plt.imshow(img, cmap='gray')
